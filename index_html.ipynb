# %% [markdown]
# <a href="https://colab.research.google.com/github/HeidyV04/ing.Quimica.github.io/blob/main/index_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
  <title>Malla Curricular - Ing. Quimica EIA</title>
  <style>
    body {
      font-family: Georgia, 'Times New Roman', Times, serif;
      background-color: rgb(251, 230, 247);
      margin: 0;
      padding: 0;
    }
    h1, h2 {
      text-align: center;
      color: #a30989;
    }
    .container {
      display: flex;
      overflow-x: auto;
    }
    .year {
      min-width: 400px;
      flex-shrink: 2;
    }
    .semestre {
      background-color: #c6f5ca;
      border: 2px solid #04970b;
      padding: 15px;
      margin: 10px 0;
      border-radius: 15px;
    }
    .semestre:nth-child(even) {
      background-color: #dfbad6;
      border: 2px solid #97046b;
      padding: 15px;
      margin: 10px 0;
      border-radius: 15px;
    }
    .materia {
      background-color: white;
      border-radius: 10px;
      padding: 10px;
      margin: 5px 0;
      cursor: pointer;
      font-weight: bold;
      color: #0e6195;
    }
    .materia.tachada {
      text-decoration: line-through;
      opacity: 0.5;
    }
    .materia.bloqueada {
      background-color: #c2ccf5;
      border: 2px dotted #5856a7;
      color: rgb(165, 163, 163);
      pointer-events: none;
    }
  </style>
</head>
<body>

  <h1>Malla Curricular - Ing. Quimica EIA</h1>

  <div class="container" id="malla"></div>

  <script>
    const materias = [
      {
        anio: "Primero", semestres: [
          {
            numero: "1º semestre", materias: [
              { id: "20252", nombre: "Cálculo I (4)" },
              { id: "20314", nombre: "Química I (4)" },
              { id: "22979", nombre: "Álgebra Lineal I (4)" },
              { id: "23423", nombre: "Cultura Física y Deportiva (1)" },
              { id: "23427", nombre: "Taller de Lenguaje (3)"},
              { id: "24948", nombre: " Vida y Cultura Universitaria (0)"},
              { id: "27534", nombre: "Introducción a la Ingeniería Química (2)"}
            ]
          },
          {
            numero: "2º semestre", materias: [
              { id: "20253", nombre: "Cálculo II (4)", previas: ["20252"]},
              { id: "22950", nombre: "Física I (4)"},
              { id: "23015", nombre: "Geometría Descriptiva (4)"},
              { id: "23079", nombre: "Química II (4)", previas: ["20314"]},
              { id: "23424", nombre: "Inglés I (4)"},
            ]
          }
        ]
      },
      {
        anio: "Segundo", semestres: [
          {
            numero: "3º semestre", materias:
              { id: "20254", nombre: "Cálculo III (4)", previas: ["20253"] },
              { id: "22953", nombre: "Física II (4)", previas: ["22950","20252"] },
              { id: "23217", nombre: "Química III(4)", previas: ["23079"] },
              { id: "23425", nombre: "Inglés II (4)", previas: ["23424"] },
              { id: "27535", nombre: "Bases Informáticas(2)"},}
         ]
        }
          {
            numero: "4º semestre", materias: [
              { id: "24463", nombre: "Contexto I (2)"},
              { id: "20255", nombre: "Ecuaciones Diferenciales (4)", previas: ["20254"] },
              { id: "21413", nombre: "Estequiometría (4)", previas: ["23217", "27534"]},
              { id: "22956", nombre: "Física III (4)", previas: ["22953", "20253"]},
              { id: "27536", nombre: "Análisis de Variables de Procesos (3)", previas: ["27535"]},
            ]
          }
        ]
      {
        anio: "Tercero", semestres: [
          {
            numero: "5º semestre", materias: [
              { id: "21416", nombre: "Fenómenos de Transporte I (4)", previas: ["20255","21413"] },
              { id: "21428", nombre: "Estructura y Propiedades de los Materiales (4)", previas: ["22956" , "23217"]},
              { id: "23219", nombre: "Termodinámica I (4)", previas: ["21413","27536"] },
              { id: "27537", nombre: "Métodos en Ingeniería Química I (3)", previas: ["20255", "27535"]}
              { id: "27538", nombre: "Manejo de Fluidos y Sólidos (4)", previas: ["21413", "22950"]},
            ]
          },
          {
            numero: "6º semestre", materias: [
              { id: "21417", nombre: "Fenómenos de Transporte II (4)", previas: ["21416","27537"]},
              { id: "23222", nombre: "Nanotecnología (4)", previas: ["21428"]},
              { id: "23226", nombre: "Termodinámica II (4)", previas: ["27537","23219"]},
              { id: "27539", nombre: "Métodos en Ingeniería Química II (3)", previas: ["27537"]},
              { id: "27540", nombre: "Fisicoquímica (3)", previas: ["22956","23079"] },
            ]
          }
        ]
      },
      {
        anio: "Cuarto", semestres: [
          {
            numero: "7º semestre", materias: [
              { id: "21419", nombre: "Operaciones Unitarias I (4)", previas: ["21417", "23226"]},
              { id: "22976", nombre: "Ingeniería Económica (3)" , previas: ["20254"]},
              { id: "23228", nombre: "Diseño de Reactores (4)", previas: ["27540","23226"]},
              { id: "27541", nombre: "Bioprocesos I (3)" , previas: ["23217"]},
              { id: "27542", nombre: "Laboratorio de Procesos I (2)", previas: ["27538", "21417"] },
              { id: "27543", nombre: "Ingeniería Computacional (3)", previas: ["27540"] },
            ]
          },
          {
            numero: "8º semestre", materias: [
              { id: "21420", nombre: "Operaciones Unitarias II (4)", previas: ["21419","27543"] },
              { id: "23229", nombre: "Control de Procesos Químicos (4)", previas: ["27539","21419"] },
              { id: "27544", nombre: "Bioprocesos II (3)", previas: ["27541","23228"]},
              { id: "27545", nombre: "Síntesis y Análisis de Procesos Químicos (3)", previas: ["21419"] },
              { id: "27546", nombre: " Gestión de Proyectos (3)", previas: ["22976"] },
            ]
          }
        ]
      },
      {
          anio: "Quinto", semestres:[
              {
            numero: "9º semestre", materias: [
              { id: "23233", nombre: "Análisis de Procesos (4)", previas: ["22976","27545"] },
              { id: "27547", nombre: "Trabajo de Grado I (1)", previas: ["21420","27545"] },
              { id: "27548", nombre: "Laboratorio de Procesos II (2)", previas: ["21420","23222"] },
              { id: "27549", nombre: "Creación de Empresas (3)", previas: ["27546"] },
              { id: "...", nombre: " Asignaturas Técnicas Pregrado (3)"},
            ]
          },
      {
            numero: "10º semestre", materias: [
              { id: "27550", nombre: "Trabajo de Grado II (6)", previas: ["27547"] },
              { id: "...", nombre: "Asignaturas Técnicas Pregrado (3)"},
              { id: "...", nombre: "Asignatura de Contexto (4)" },
            ]
          }
        ]
      };

    const estadoMaterias = JSON.parse(localStorage.getItem("estadoMaterias") || "{}");

    function crearMalla() {
      const contenedor = document.getElementById("malla");
      contenedor.innerHTML = "";

      materias.forEach(anio => {
        const divAnio = document.createElement("div");
        divAnio.className = "year";

        const h2 = document.createElement("h2");
        h2.textContent = anio.anio;
        divAnio.appendChild(h2);
0
        anio.semestres.forEach(sem => {
          const divSem = document.createElement("div");
          divSem.className = "semestre";

          const h3 = document.createElement("h3");
          h3.textContent = sem.numero;
          divSem.appendChild(h3);

          sem.materias.forEach(materia) => {
            const divMat = document.createElement("div");
            divMat.textContent = materia.nombre;
            divMat.className = "materia";
            divMat.dataset.id = materia.id;

            if (estadoMaterias[materia.id]) {
              divMat.classList.add("tachada");
            }

            // Verifica si cumple previas
            if materia.previas && materia.previas.some (p) => !estadoMaterias[p]
              divMat.classList.add("bloqueada");
            }

            divMat.addEventListener("click", () => {
              if (divMat.classList.contains("bloqueada")) return;
              divMat.classList.toggle("tachada");
              estadoMaterias[materia.id] = divMat.classList.contains("tachada");
              localStorage.setItem("estadoMaterias", JSON.stringify(estadoMaterias));
              crearMalla(); // Volver a renderizar para actualizar dependencias
            });

            divSem.appendChild(divMat);
          });

          divAnio.appendChild(divSem);
        });

        contenedor.appendChild(divAnio);
      };

    crearMalla();
  </script>
  ...
  <div id="contenedor-de-botones"></div>

  <script src="logica.js"></script>

</body>
</html>
# Out:
#   File "/tmp/ipython-input-1-1025238157.py", line 22
#     padding: 30px;
#               ^
# SyntaxError: invalid decimal literal
